# %% [markdown]
# <img src="https://raw.githubusercontent.com/rhatiro/Curso_EBAC-Profissao_Cientista_de_Dados/main/ebac-course-utils/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Profissão: Cientista de Dados**
# ### **Módulo 10** | Exercício 3
#
# Aluno [Lays Félix](https://www.linkedin.com/in/laysfelixbusiness)<br>
# Data: 25 de fevereiro de 2024
#
# ---

# %% [markdown]
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# ### Importando bibliotecas <a name="import"></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Carregando o dataframe <a name="read"></a>

# %%
#previsao_de_renda = pd.read_csv('https://raw.githubusercontent.com/laysfelix/dataFrame/b580f1d8ea5e92dd51dea777273ad6d9684797a9/RO_2019.csv')
#previsao_de_renda.head()
# Out:
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0    M                Y               Y           0               Working
# 1    F                N               Y           0  Commercial associate
# 2    F                N               Y           0  Commercial associate
# 3    M                Y               Y           0               Working
# 4    F                Y               N           0               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# 1  Secondary / secondary special  Single / not married  House / apartment
# 2  Secondary / secondary special  Single / not married  House / apartment
# 3               Higher education               Married  House / apartment
# 4              Incomplete higher               Married  House / apartment
#
#        idade  tempo_emprego  possui_celular  possui_fone_comercial  \
# ...

# %%
previsao_de_renda = pd.read_csv('previsao_de_renda.csv')
previsao_de_renda.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
# Transformando a coluna data_ref em datetime
previsao_de_renda['data_ref'] = pd.to_datetime(previsao_de_renda['data_ref'])

# %%
previsao_de_renda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  datetime64[ns]
#  2   index                  15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12466 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
# ...

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis QUALITATIVAS no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %% [markdown]
# Analisando as variáveis qualitativas, segundo os gráficos abaixo, verificamos que a houve uma queda entre os meses agosto e setembro da variável Educação.

# %%
ax = sns.countplot(x='data_ref', hue='sexo', data=previsao_de_renda)
plt.title(f'Sexo por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=50)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(x='data_ref', hue='posse_de_veiculo', data=previsao_de_renda)
plt.title(f'Posse de veículo por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=50)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(x='data_ref', hue='posse_de_imovel', data=previsao_de_renda)
plt.title(f'Posse de imóvel por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=50)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(x='data_ref', hue='tipo_renda', data=previsao_de_renda)
plt.title(f'Tipo de renda por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(x='data_ref', hue='educacao', data=previsao_de_renda)
plt.title(f'Educação por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=55)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(x='data_ref', hue='estado_civil', data=previsao_de_renda)
plt.title(f'Estado civil por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=55)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(x='data_ref', hue='tipo_residencia', data=previsao_de_renda)
plt.title(f'Tipo de residência por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=55)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(x='data_ref', hue='mau', data=previsao_de_renda)
plt.title(f'Mau por tempo')

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=50)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# 2) Para cada variável QUALITATIVA, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %% [markdown]
# As variáveis Tipo de renda e Educação chamaram mais atenção com as
# médias distantes de um mês para o outro.

# %%
# novo dataframe apenas com variáveis qualitativas
df_qualitativa = previsao_de_renda.select_dtypes(include='object')

# %%
# Plotando os gráficos de contagem para todas as variáveis qualitativas
cont = 1
for col in df_qualitativa.columns[1:]:
  plt.subplot(1,1,cont)
  cont=+ 1
  sns.pointplot(x="data_ref", y="renda", hue = col,
                    data=previsao_de_renda, dodge=True, errorbar=('ci', 95))
  plt.title(f'Média de renda para diferentes valores do {col} no tempo')
  plt.xticks(rotation=45)
  plt.xlabel('Data de referência')
  plt.legend(loc = 'upper center', bbox_to_anchor=(0.5, -.50),ncol = 3)
  plt.show()

# %%
# mesmos gráficos acima, porém feitos de forma diferente

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'sexo',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do SEXO no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_veiculo',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do POSSE DE VEÍCULO no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_imovel',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do POSSE DE IMÓVEL no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_renda',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do TIPO DE RENDA no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'educacao',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do EDUCAÇÃO no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'estado_civil',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do ESTADO CIVIL no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_residencia',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do TIPO RESIDÊNCIA no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'mau',
                   data=previsao_de_renda, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = previsao_de_renda['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(previsao_de_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=45)
plt.title(f'Média de renda para diferentes valores do MAU no tempo')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
