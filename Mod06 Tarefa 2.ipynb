# %% [markdown]
# <img src="https://raw.githubusercontent.com/rhatiro/Curso_EBAC-Profissao_Cientista_de_Dados/main/ebac-course-utils/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Profissão: Cientista de Dados**
# ### **Módulo 6** | Exercício 2
#
# Aluno [Lays Félix](https://www.linkedin.com/in/laysfelixbusiness)<br>
# Data: 17 de dezembro de 2023
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %matplotlib notebook

# %%
#df_sinasc = pd.read_csv('https://xxx/RO_2019.csv')
#print(df_sinasc.info())
#df_sinasc

nascidos_RO2019 = pd.read_csv('RO_2019.csv')
nascidos_RO2019
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0           1  2679477.0      110001        1        19        5.0
# 1           1  2679477.0      110001        1        29        2.0
# 2           1  2679477.0      110001        1        37        9.0
# 3           1  2516500.0      110001        1        30        5.0
# 4           1  2516500.0      110001        1        30        2.0
# ...       ...        ...         ...      ...       ...        ...
# 27023       1  2604388.0      510340        1        32        2.0
# 27024       1  2752654.0      510675        1        19        1.0
# 27025       1  9659366.0      510787        1        24        2.0
# 27026       1  9659366.0      510787        1        21        2.0
# 27027       1  2795655.0      510792        1        18        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0          8 a 11 anos         NaN         0.0         0.0  ...           5
# ...

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
nascidos_RO2019[['IDADEMAE']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
nascidos_RO2019[['PESO']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
nascidos_RO2019['IDADEMAE'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
nascidos_RO2019[nascidos_RO2019['IDADEMAE']>45]
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 1573        1  2516381.0      110004        1        47        1.0
# 8493        1  4001303.0      110020        1        47        4.0
# 13801       1  2516500.0      110001        1        53        2.0
# 13835       1  2515520.0      110002        1        46        1.0
# 15344       1  2784637.0      110004        1        47        2.0
# 18592       1  2808633.0      110014        1        51        2.0
# 18901       1  2496879.0      110015        1        52        1.0
# 19423       1  2516047.0      110018        1        47        2.0
# 20796       1  2743590.0      110020        1        46        1.0
# 21803       1  4001303.0      110020        1        46        5.0
# 24472       1  2495228.0      110028        1        46        1.0
# 25372       1  2798484.0      110030        1        53        2.0
# 25535       1  2798484.0      110030        1        46        2.0
# ...

# %%
sns.displot(data = nascidos_RO2019[nascidos_RO2019['IDADEMAE']<50] 
            ,alpha = .25
            ,x = 'IDADEMAE'
            ,bins = 20        
            ,element = 'step'
            ,kde = True
           )

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
nascidos_RO2019['PESO'].plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
nascidos_RO2019[nascidos_RO2019['PESO']>5000]
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 2852        1  2515768.0      110010        1        28        1.0
# 4781        1  2808617.0      110013        1        39        2.0
# 6482        1  4001303.0      110020        1        25        2.0
# 7903        1  4001303.0      110020        1        26        1.0
# 8636        1  4001303.0      110020        1        20        1.0
# 13682       1  2000733.0      120040        1        31        2.0
# 15467       1  2496046.0      110004        1        40        4.0
# 16105       1  2808587.0      110009        1        32        2.0
# 17058       1  2808609.0      110011        1        32        5.0
# 18251       1  2495279.0      110012        1        29        2.0
# 24678       1  2495228.0      110028        1        37        4.0
# 26304       1  5915104.0      110045        1        33        1.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# ...

# %%
sns.displot(data = nascidos_RO2019[nascidos_RO2019['PESO']<6000] 
            ,alpha = .25
            ,x = 'PESO'
            ,bins = 20
            ,element = 'step'
            ,kde = True
           )
